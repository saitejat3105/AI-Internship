# %%
#random forest we can decide next step
# we have more than one tree if 5 decison trees we calculate mean we can get good accuracy we perform ensable method after it

# %%
'''
random forest classifier and random forest regressior
we split our data into some parts and make decision trees from each parts
at decison tree we get result we take mean of all the results of decision tree to get optimized result
it always give good accuracy even we have less data outliers some missing values beacuse it is following the tree terminology
'''
# Out:
# '\nrandom forest classifier and random forest regressior \nwe split our data into some parts and make decision trees from each parts\nat decison tree we get result we take mean of all the results of decision tree to get optimized result\nit always give good accuracy even we have less data outliers some missing values beacuse it is following the tree terminology\n'

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/breast_cancer.csv")
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# ...

# %%
df.shape
# Out:
# (569, 31)

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %%
df.outcome.value_counts() #the zeroes must be 357 and 1 be 212 to get good prediction change data set later
# Out:
# outcome
# 0    303
# 1    266
# Name: count, dtype: int64

# %%
df.corr()
# Out:
#                          mean radius  mean texture  mean perimeter  mean area  \
# mean radius                 1.000000      0.323782        0.997855   0.987357
# mean texture                0.323782      1.000000        0.329533   0.321086
# mean perimeter              0.997855      0.329533        1.000000   0.986507
# mean area                   0.987357      0.321086        0.986507   1.000000
# mean smoothness             0.170581     -0.023389        0.207278   0.177028
# mean compactness            0.506124      0.236702        0.556936   0.498502
# mean concavity              0.676764      0.302418        0.716136   0.685983
# mean concave points         0.822529      0.293464        0.850977   0.823269
# mean symmetry               0.147741      0.071401        0.183027   0.151293
# mean fractal dimension     -0.311631     -0.076437       -0.261477  -0.283110
# radius error                0.679090      0.275869        0.691765   0.732562
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 569 entries, 0 to 568
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   mean radius              569 non-null    float64
#  1   mean texture             569 non-null    float64
#  2   mean perimeter           569 non-null    float64
#  3   mean area                569 non-null    float64
#  4   mean smoothness          569 non-null    float64
#  5   mean compactness         569 non-null    float64
#  6   mean concavity           569 non-null    float64
#  7   mean concave points      569 non-null    float64
#  8   mean symmetry            569 non-null    float64
#  9   mean fractal dimension   569 non-null    float64
#  10  radius error             569 non-null    float64
#  11  texture error            569 non-null    float64
#  12  perimeter error          569 non-null    float64
# ...

# %%
#X and y split
X=df.iloc[:,:-1]
X.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
y=df.outcome
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# Name: outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.3,random_state=0)

# %%
X_train.shape
# Out:
# (398, 30)

# %%
X_test.shape
# Out:
# (171, 30)

# %%
#model building
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier()
model.fit(X_train,y_train) #we fit model on train data
# Out:
# RandomForestClassifier()

# %%
#test with test data
y_pred=model.predict(X_test)

# %%
y_pred1=model.predict(X_train)

# %%
#evaluate model
from sklearn.metrics import accuracy_score,classification_report

# %%
print("test accuracy",accuracy_score(y_test,y_pred))
print("train acc",accuracy_score(y_train,y_pred1))
# Out:
# test accuracy 0.5847953216374269
# train acc 1.0

# %%
#we have to adjust this it shouldnt be 1 it should be near 0.9 both
#train overfitting

# %%
#now again give parameter n estimator=10 splitting criteria=entropy

# %%
from sklearn.ensemble import RandomForestClassifier
model=RandomForestClassifier(n_estimators=10,criterion="entropy")
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', n_estimators=10)

# %%
y_pred=model.predict(X_test)

# %%
y_pred1=model.predict(X_train)

# %%
from sklearn.metrics import accuracy_score,classification_report

# %%
print("test accuracy",accuracy_score(y_test,y_pred))
print("train acc",accuracy_score(y_train,y_pred1))
# Out:
# test accuracy 0.543859649122807
# train acc 0.9748743718592965

# %%
pd.crosstab(y_test,y_pred)
# Out:
# col_0     0   1
# outcome
# 0        64  29
# 1        49  29

# %%
#we should reduce the error ie 29 and 29 should be reduced by changing parametres etc
#this is hyper parameter tuning

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.57      0.69      0.62        93
#            1       0.50      0.37      0.43        78
#
#     accuracy                           0.54       171
#    macro avg       0.53      0.53      0.52       171
# weighted avg       0.54      0.54      0.53       171

# %%
#compare with decison tree we get good prediction in rsandom forest
